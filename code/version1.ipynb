# %%
# !pip install cherche --upgrade -q
# !pip install ir_datasets -q
# !pip install pytrec_eval
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: pytrec_eval in /usr/local/lib/python3.10/dist-packages (0.5)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.40.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (10.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)

# %%
import pytrec_eval
import ir_datasets
import pandas as pd
import json
from cherche import data, retrieve, rank
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from scipy.sparse import csc_matrix
from sklearn.metrics.pairwise import linear_kernel
from scipy.sparse import csc_matrix
import typing
import ir_datasets

# %%
#installation de pyterrier avec pip
# !pip install --upgrade git+https://github.com/terrier-org/pyterrier.git#egg=python-terrier
#Initialization de JVM
import pyterrier as pt
if not pt.started():
  pt.init()
# Out:
# Collecting python-terrier
#   Cloning https://github.com/terrier-org/pyterrier.git to /tmp/pip-install-7gwh4tai/python-terrier_dec6d14d330e4a56a7570fd826b907ff
#   Running command git clone --filter=blob:none --quiet https://github.com/terrier-org/pyterrier.git /tmp/pip-install-7gwh4tai/python-terrier_dec6d14d330e4a56a7570fd826b907ff
#   Resolved https://github.com/terrier-org/pyterrier.git to commit a17f9b7ed1782010b4680457874f220b65fa2594
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from python-terrier) (2.0.3)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from python-terrier) (3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from python-terrier) (4.66.4)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.6.1)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.2.14)
# Requirement already satisfied: chest in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.11.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.4.2)
# Requirement already satisfied: nptyping==1.4.4 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.4.4)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.10/dist-packages (from python-terrier) (10.1.0)
# Requirement already satisfied: ir_datasets>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.5.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (3.1.4)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.14.2)
# Requirement already satisfied: ir_measures>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.3.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.3.8)
# Requirement already satisfied: pytrec_eval_terrier>=0.5.3 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.5.6)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (2.5.0)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.9.4)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (6.0.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.3.3)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (0.1.6)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (3.2.3)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.10/dist-packages (from ir_measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (2024.2.2)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.10/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->python-terrier) (2.1.5)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2024.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (24.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir_datasets>=0.3.2->python-terrier) (2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir_datasets>=0.3.2->python-terrier) (1.0.0)

# %%
import pyterrier as pt
import ir_datasets

# Initialize PyTerrier
if not pt.started():
    pt.init()

# Load the vaswani dataset
dataset = ir_datasets.load('vaswani')

# Define a generator to yield documents in the format required by PyTerrier
def generate_documents():
    for doc in dataset.docs_iter():
        yield {'docno': doc.doc_id, 'text': doc.text}

# Convert the generator to a list
documents = list(generate_documents())

# Define the index directory
index_dir = './index/vaswani'

# Create the index
indexer = pt.IterDictIndexer(index_dir)
index_ref = indexer.index(documents)

# Load the index
index = pt.IndexFactory.of(index_ref)

# Check the number of documents
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 11429
# Number of terms: 7756
# Number of postings: 224573
# Number of fields: 1
# Number of tokens: 271581
# Field names: [text]
# Positions:   false

# %%
print(dataset)
# Out:
# Dataset(id='vaswani', provides=['docs', 'queries', 'qrels'])

# %% [markdown]
# **Retrieval**

# %%
# Set up the BM25 retrieval model
bm25 = pt.BatchRetrieve(index, wmodel="BM25")
for query in dataset.queries_iter():
    query_text = query.text
    query_id = query.query_id

    # Perform the retrieval
    results = bm25.search(query_text)

    # Print the top-ranked documents for the current query
    print(f"Query ID: {query_id}")
    print(f"Query Text: {query_text}")
    print(results)
# Out:
# Query ID: 1
# Query Text: MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS BY THE USE OF MICROWAVE TECHNIQUES
#
#     qid  docid docno  rank      score  \
# 0     1   8171  8172     0  24.566031
# 1     1   9880  9881     1  22.110514
# 2     1   5501  5502     2  21.717148
# 3     1   1501  1502     3  19.478355
# 4     1   9858  9859     4  18.626342
# ..   ..    ...   ...   ...        ...
# 995   1      6     7   995   4.647515
# 996   1     50    51   996   4.647515
# 997   1   1028  1029   997   4.647515
# 998   1   1536  1537   998   4.647515
# 999   1   3042  3043   999   4.647515
#
#                                                  query
# 0    MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# 1    MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# 2    MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# 3    MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# 4    MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# ..                                                 ...
# 995  MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# 996  MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# 997  MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# 998  MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
# 999  MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS ...
#
# [1000 rows x 6 columns]
# Query ID: 2
# Query Text: MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WAVEGUIDE FED MICROWAVE RADIATIONS
#
#     qid  docid docno  rank      score  \
# 0     1   2849  2850     0  17.721152
# 1     1   3780  3781     1  17.412621
# 2     1   7112  7113     2  17.229455
# 3     1   5123  5124     3  17.003840
# 4     1   5011  5012     4  16.882607
# ..   ..    ...   ...   ...        ...
# 995   1   3528  3529   995   5.161525
# 996   1   4832  4833   996   5.161525
# 997   1   7723  7724   997   5.161525
# 998   1   8854  8855   998   5.161525
# 999   1   9198  9199   999   5.161525
#
#                                                  query
# 0    MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# 1    MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# 2    MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# 3    MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# 4    MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# ..                                                 ...
# 995  MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# 996  MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# 997  MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# 998  MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
# 999  MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WA...
#
# [1000 rows x 6 columns]
# Query ID: 3
# Query Text: USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND PASS FILTERS HAVING GIVEN PHASE AND ATTENUATION CHARACTERISTICS
#
#     qid  docid  docno  rank      score  \
# 0     1   7085   7086     0  32.509774
# 1     1  11037  11038     1  32.467303
# 2     1   6347   6348     2  31.901809
# 3     1   4724   4725     3  31.116455
# 4     1   3969   3970     4  30.605772
# ..   ..    ...    ...   ...        ...
# 995   1   9819   9820   995   7.219914
# 996   1  10190  10191   996   7.219914
# 997   1     18     19   997   7.211881
# 998   1   7392   7393   998   7.206904
# 999   1   6531   6532   999   7.204238
#
#                                                  query
# 0    USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# 1    USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# 2    USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# 3    USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# 4    USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# ..                                                 ...
# 995  USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# 996  USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# 997  USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# 998  USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
# 999  USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND...
#
# [1000 rows x 6 columns]
# Query ID: 4
# Query Text: SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER
#
#     qid  docid  docno  rank      score  \
# 0     1   3594   3595     0  24.991371
# 1     1   7526   7527     1  20.816202
# 2     1   7984   7985     2  17.866263
# 3     1   4056   4057     3  16.320166
# 4     1   5575   5576     4  16.017203
# ..   ..    ...    ...   ...        ...
# 995   1   9172   9173   995   3.795132
# 996   1   9213   9214   996   3.795132
# 997   1   9245   9246   997   3.795132
# 998   1   9823   9824   998   3.795132
# 999   1  10408  10409   999   3.795132
#
#                                                  query
# 0    SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# 1    SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# 2    SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# 3    SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# 4    SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# ..                                                 ...
# 995  SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# 996  SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# 997  SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# 998  SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
# 999  SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER\n
#
# [1000 rows x 6 columns]
# Query ID: 5
# Query Text: USE OF PROGRAMS IN ENGINEERING TESTING OF COMPUTERS
#
#     qid  docid  docno  rank      score  \
# 0     1   1585   1586     0  26.192890
# 1     1  11428  11429     1  23.252472
# 2     1   7874   7875     2  18.996809
# 3     1   3558   3559     3  18.066157
# 4     1   2289   2290     4  17.749907
# ..   ..    ...    ...   ...        ...
# 717   1  10015  10016   717   2.379234
# 718   1   3484   3485   718   2.335306
# 719   1   8380   8381   719   2.313945
# 720   1   3333   3334   720   2.096265
# 721   1   8135   8136   721   1.986817
#
#                                                  query
# 0    USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# 1    USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# 2    USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# 3    USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# 4    USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# ..                                                 ...
# 717  USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# 718  USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# 719  USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# 720  USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
# 721  USE OF PROGRAMS IN ENGINEERING TESTING OF COMP...
#
# [722 rows x 6 columns]
# Query ID: 6
# Query Text: NUMBER REPRESENTATION IN BINARY MACHINES
#
#     qid  docid  docno  rank      score  \
# 0     1   5439   5440     0  22.510565
# 1     1   2681   2682     1  19.708496
# 2     1   8533   8534     2  16.994282
# 3     1   4315   4316     3  16.382688
# 4     1  10161  10162     4  16.360643
# ..   ..    ...    ...   ...        ...
# 603   1   9803   9804   603   2.477271
# 604   1   7522   7523   604   2.393525
# 605   1   7055   7056   605   2.373466
# 606   1   6500   6501   606   2.207003
# 607   1   9800   9801   607   2.077487
#
#                                           query
# 0    NUMBER REPRESENTATION IN BINARY MACHINES\n
# 1    NUMBER REPRESENTATION IN BINARY MACHINES\n
# 2    NUMBER REPRESENTATION IN BINARY MACHINES\n
# 3    NUMBER REPRESENTATION IN BINARY MACHINES\n
# 4    NUMBER REPRESENTATION IN BINARY MACHINES\n
# ..                                          ...
# 603  NUMBER REPRESENTATION IN BINARY MACHINES\n
# 604  NUMBER REPRESENTATION IN BINARY MACHINES\n
# 605  NUMBER REPRESENTATION IN BINARY MACHINES\n
# 606  NUMBER REPRESENTATION IN BINARY MACHINES\n
# 607  NUMBER REPRESENTATION IN BINARY MACHINES\n
#
# [608 rows x 6 columns]
# Query ID: 7
# Query Text: SECONDARY EMISSION OF ELECTRONS BY POSITIVE ION BOMBARDMENT OF THE CATHODE
#
#     qid  docid  docno  rank      score  \
# 0     1   2095   2096     0  35.070905
# 1     1   6568   6569     1  34.234319
# 2     1   5291   5292     2  33.993006
# 3     1   5902   5903     3  32.882561
# 4     1   6730   6731     4  30.895059
# ..   ..    ...    ...   ...        ...
# 995   1  10426  10427   995   4.306244
# 996   1  10545  10546   996   4.300131
# 997   1  10714  10715   997   4.295043
# 998   1   6806   6807   998   4.279419
# 999   1   1100   1101   999   4.272909
#
#                                                  query
# 0    SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# 1    SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# 2    SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# 3    SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# 4    SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# ..                                                 ...
# 995  SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# 996  SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# 997  SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# 998  SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
# 999  SECONDARY EMISSION OF ELECTRONS BY POSITIVE IO...
#
# [1000 rows x 6 columns]
# Query ID: 8
# Query Text: MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISCHARGE USING SHOCK WAVE TECHNIQUES
#
#     qid  docid  docno  rank      score  \
# 0     1  11349  11350     0  37.499580
# 1     1   3773   3774     1  30.288944
# 2     1   1997   1998     2  23.701107
# 3     1  10787  10788     3  22.901523
# 4     1   9587   9588     4  21.768869
# ..   ..    ...    ...   ...        ...
# 995   1   6285   6286   995   6.379935
# 996   1   6283   6284   996   6.368512
# 997   1   1682   1683   997   6.363909
# 998   1   1896   1897   998   6.363909
# 999   1   2429   2430   999   6.363909
#
#                                                  query
# 0    MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# 1    MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# 2    MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# 3    MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# 4    MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# ..                                                 ...
# 995  MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# 996  MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# 997  MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# 998  MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
# 999  MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISC...
#
# [1000 rows x 6 columns]
# Query ID: 9
# Query Text: CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHARGE IN THE RARE GASES AT LOW PRESSURES
#
#     qid  docid docno  rank      score  \
# 0     1   7013  7014     0  34.377845
# 1     1   7932  7933     1  29.256932
# 2     1   3088  3089     2  27.735794
# 3     1   6110  6111     3  27.485322
# 4     1   5299  5300     4  26.357730
# ..   ..    ...   ...   ...        ...
# 995   1   1844  1845   995   4.616156
# 996   1   2297  2298   996   4.616156
# 997   1   2441  2442   997   4.616156
# 998   1   2678  2679   998   4.616156
# 999   1   3029  3030   999   4.616156
#
#                                                  query
# 0    CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# 1    CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# 2    CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# 3    CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# 4    CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# ..                                                 ...
# 995  CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# 996  CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# 997  CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# 998  CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
# 999  CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHA...
#
# [1000 rows x 6 columns]
# Query ID: 10
# Query Text: METHODS OF CALCULATING INSTANTANEOUS POWER DISSIPATION IN REACTIVE CIRCUITS
#
#     qid  docid  docno  rank      score  \
# 0     1   9529   9530     0  22.302417
# 1     1  10616  10617     1  22.195690
# 2     1   2668   2669     2  21.707825
# 3     1    630    631     3  20.268278
# 4     1   7088   7089     4  20.256459
# ..   ..    ...    ...   ...        ...
# 995   1   1271   1272   995   4.588469
# 996   1   4893   4894   996   4.574829
# 997   1   7001   7002   997   4.569366
# 998   1  10994  10995   998   4.569366
# 999   1   6795   6796   999   4.562833
#
#                                                  query
# 0    METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# 1    METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# 2    METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# 3    METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# 4    METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# ..                                                 ...
# 995  METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# 996  METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# 997  METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# 998  METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
# 999  METHODS OF CALCULATING INSTANTANEOUS POWER DIS...
#
# [1000 rows x 6 columns]
# Query ID: 11
# Query Text: THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CONTACTS
#
#     qid  docid docno  rank      score  \
# 0     1   1097  1098     0  18.619664
# 1     1    514   515     1  17.880564
# 2     1    826   827     2  16.908275
# 3     1   7454  7455     3  15.818431
# 4     1   4138  4139     4  14.644430
# ..   ..    ...   ...   ...        ...
# 995   1   1710  1711   995   3.386674
# 996   1   3825  3826   996   3.386674
# 997   1   4986  4987   997   3.386674
# 998   1   5911  5912   998   3.386674
# 999   1   8765  8766   999   3.386674
#
#                                                  query
# 0    THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# 1    THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# 2    THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# 3    THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# 4    THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# ..                                                 ...
# 995  THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# 996  THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# 997  THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# 998  THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
# 999  THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CON...
#
# [1000 rows x 6 columns]
# Query ID: 12
# Query Text: TEMPERATURE INDEPENDENT METHODS FOR TUNING HIGHLY STABLE HIGH FREQUENCY OSCILLATORS
#
#     qid  docid  docno  rank      score  \
# 0     1  11317  11318     0  23.988490
# 1     1   7494   7495     1  22.273583
# 2     1   4732   4733     2  21.841264
# 3     1   6042   6043     3  21.037146
# 4     1   4956   4957     4  20.318870
# ..   ..    ...    ...   ...        ...
# 995   1   4026   4027   995   6.212661
# 996   1   5476   5477   996   6.204912
# 997   1   9777   9778   997   6.197159
# 998   1  10570  10571   998   6.189021
# 999   1    692    693   999   6.188106
#
#                                                  query
# 0    TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# 1    TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# 2    TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# 3    TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# 4    TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# ..                                                 ...
# 995  TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# 996  TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# 997  TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# 998  TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
# 999  TEMPERATURE INDEPENDENT METHODS FOR TUNING HIG...
#
# [1000 rows x 6 columns]
# Query ID: 13
# Query Text: MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DESIGN OF TRANSISTORISED TUNED PASS BAND AMPLIFIERS
#
#     qid  docid  docno  rank      score  \
# 0     1   3630   3631     0  27.973720
# 1     1   5872   5873     1  27.827347
# 2     1   3397   3398     2  25.319717
# 3     1   8345   8346     3  23.903812
# 4     1   2457   2458     4  23.382306
# ..   ..    ...    ...   ...        ...
# 995   1   2433   2434   995   5.293864
# 996   1   2453   2454   996   5.293864
# 997   1  10170  10171   997   5.293864
# 998   1   4623   4624   998   5.293681
# 999   1   7371   7372   999   5.291103
#
#                                                  query
# 0    MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# 1    MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# 2    MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# 3    MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# 4    MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# ..                                                 ...
# 995  MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# 996  MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# 997  MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# 998  MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
# 999  MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DE...
#
# [1000 rows x 6 columns]
# Query ID: 14
# Query Text: SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION CHARACTERISTICS USING A BLOCK DIAGRAM APPROACH
#
#     qid  docid  docno  rank      score  \
# 0     1   5748   5749     0  23.606963
# 1     1   8202   8203     1  23.169235
# 2     1   4436   4437     2  20.365810
# 3     1   6259   6260     3  20.268599
# 4     1  11313  11314     4  19.893925
# ..   ..    ...    ...   ...        ...
# 995   1  10234  10235   995   5.493055
# 996   1   6141   6142   996   5.492025
# 997   1   6171   6172   997   5.480104
# 998   1   7713   7714   998   5.480104
# 999   1    421    422   999   5.457291
#
#                                                  query
# 0    SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# 1    SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# 2    SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# 3    SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# 4    SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# ..                                                 ...
# 995  SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# 996  SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# 997  SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# 998  SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
# 999  SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION C...
#
# [1000 rows x 6 columns]
# Query ID: 15
# Query Text: VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF NONLINEAR ELEMENTS CONNECTED IN PARALLEL
#
#     qid  docid docno  rank      score  \
# 0     1   4814  4815     0  23.307160
# 1     1    259   260     1  21.023826
# 2     1   6987  6988     2  20.935907
# 3     1   3732  3733     3  19.371356
# 4     1   9852  9853     4  19.161893
# ..   ..    ...   ...   ...        ...
# 995   1   7340  7341   995   5.840439
# 996   1   7344  7345   996   5.840439
# 997   1   7803  7804   997   5.840439
# 998   1   8225  8226   998   5.840439
# 999   1   8438  8439   999   5.840439
#
#                                                  query
# 0    VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# 1    VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# 2    VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# 3    VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# 4    VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# ..                                                 ...
# 995  VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# 996  VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# 997  VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# 998  VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
# 999  VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF N...
#
# [1000 rows x 6 columns]
# Query ID: 16
# Query Text: METHODS OF APPROXIMATING THE FREQUENCY PHASE RELATIONSHIPS FOR RESISTIVE INDUCTIVE AND RESISTIVE CAPACITIVE CIRCUITS
#
#     qid  docid  docno  rank      score  \
# 0     1   1477   1478     0  14.896207
# 1     1   5258   5259     1  14.117499
# 2     1   5022   5023     2  13.792741
# 3     1   5043   5044     3  13.532581
# 4     1   5684   5685     4  12.886887
# ..   ..    ...    ...   ...        ...
# 995   1    438    439   995   3.738616
# 996   1   4488   4489   996   3.736305
# 997   1  10660  10661   997   3.736305
# 998   1   7765   7766   998   3.735836
# 999   1   4483   4484   999   3.735674
#
#                                                  query
# 0    METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# 1    METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# 2    METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# 3    METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# 4    METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# ..                                                 ...
# 995  METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# 996  METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# 997  METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# 998  METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
# 999  METHODS OF APPROXIMATING THE FREQUENCY PHASE R...
#
# [1000 rows x 6 columns]
# Query ID: 17
# Query Text: OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EARTHS MAGNETIC FIELD AND THEIR RELATION TO THE PROPAGATION OF HYDROMAGNETIC WAVES IN THE
# EXOSPHERE
#
#     qid  docid  docno  rank      score  \
# 0     1  10980  10981     0  43.672636
# 1     1  11129  11130     1  34.894465
# 2     1    495    496     2  32.172476
# 3     1     92     93     3  31.348408
# 4     1  11127  11128     4  31.034803
# ..   ..    ...    ...   ...        ...
# 995   1    333    334   995   7.404313
# 996   1   6801   6802   996   7.402258
# 997   1   9483   9484   997   7.400388
# 998   1   3570   3571   998   7.394428
# 999   1   6920   6921   999   7.394428
#
#                                                  query
# 0    OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# 1    OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# 2    OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# 3    OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# 4    OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# ..                                                 ...
# 995  OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# 996  OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# 997  OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# 998  OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
# 999  OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EART...
#
# [1000 rows x 6 columns]
# Query ID: 18
# Query Text: DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EARTHS MAGNETIC FIELD
#
#     qid  docid  docno  rank      score  \
# 0     1   6211   6212     0  24.043000
# 1     1   2121   2122     1  23.258138
# 2     1    738    739     2  21.072691
# 3     1     92     93     3  19.865520
# 4     1   7425   7426     4  19.807611
# ..   ..    ...    ...   ...        ...
# 995   1  10917  10918   995   5.922361
# 996   1    223    224   996   5.914708
# 997   1   4279   4280   997   5.914708
# 998   1  10720  10721   998   5.914708
# 999   1   4620   4621   999   5.909429
#
#                                                  query
# 0    DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# 1    DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# 2    DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# 3    DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# 4    DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# ..                                                 ...
# 995  DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# 996  DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# 997  DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# 998  DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
# 999  DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EART...
#
# [1000 rows x 6 columns]
# Query ID: 19
# Query Text: SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGNETIC FIELD
#
#     qid  docid  docno  rank      score  \
# 0     1  10692  10693     0  20.253853
# 1     1   7614   7615     1  19.446989
# 2     1   1003   1004     2  19.266355
# 3     1   8756   8757     3  18.716843
# 4     1   1669   1670     4  18.711333
# ..   ..    ...    ...   ...        ...
# 995   1  11048  11049   995   5.722459
# 996   1   4767   4768   996   5.714156
# 997   1   1875   1876   997   5.712385
# 998   1  10783  10784   998   5.708200
# 999   1   4346   4347   999   5.705744
#
#                                                  query
# 0    SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# 1    SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# 2    SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# 3    SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# 4    SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# ..                                                 ...
# 995  SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# 996  SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# 997  SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# 998  SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
# 999  SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGN...
#
# [1000 rows x 6 columns]
# Query ID: 20
# Query Text: DERIVATION OF THE COMPONENTS OF THE ELECTRICAL CONDUCTIVITY IN THE UPPER ATMOSPHERE
#
#     qid  docid docno  rank      score  \
# 0     1   7425  7426     0  26.504702
# 1     1   4796  4797     1  23.018604
# 2     1   6490  6491     2  20.890460
# 3     1    607   608     3  19.407364
# 4     1    882   883     4  18.491043
# ..   ..    ...   ...   ...        ...
# 995   1   1387  1388   995   4.929256
# 996   1   2679  2680   996   4.929256
# 997   1   2855  2856   997   4.929256
# 998   1   4851  4852   998   4.929256
# 999   1   5520  5521   999   4.929256
#
#                                                  query
# 0    DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# 1    DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# 2    DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# 3    DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# 4    DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# ..                                                 ...
# 995  DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# 996  DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# 997  DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# 998  DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
# 999  DERIVATION OF THE COMPONENTS OF THE ELECTRICAL...
#
# [1000 rows x 6 columns]
# Query ID: 21
# Query Text: THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION OF COSMIC RADIO NOISE IN THE IONOSPHERE
#
#     qid  docid  docno  rank      score  \
# 0     1   7863   7864     0  29.491353
# 1     1   2108   2109     1  28.532932
# 2     1   3017   3018     2  28.030753
# 3     1    477    478     3  26.759850
# 4     1  10714  10715     4  26.670532
# ..   ..    ...    ...   ...        ...
# 995   1  10930  10931   995   6.573871
# 996   1   8839   8840   996   6.569438
# 997   1   9092   9093   997   6.569438
# 998   1   9582   9583   998   6.569438
# 999   1   3088   3089   999   6.566052
#
#                                                  query
# 0    THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# 1    THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# 2    THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# 3    THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# 4    THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# ..                                                 ...
# 995  THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# 996  THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# 997  THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# 998  THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
# 999  THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION ...
#
# [1000 rows x 6 columns]
# Query ID: 22
# Query Text: DETERMINATION OF THE CURRENT SYSTEMS IN THE UPPER ATMOSPHERE DURING MAGNETIC STORMS
#
#     qid  docid  docno  rank      score  \
# 0     1    607    608     0  22.027520
# 1     1   3445   3446     1  21.596739
# 2     1   6220   6221     2  21.051522
# 3     1   6025   6026     3  20.033040
# 4     1  10987  10988     4  19.696916
# ..   ..    ...    ...   ...        ...
# 995   1    599    600   995   5.577758
# 996   1   2269   2270   996   5.577758
# 997   1   9846   9847   997   5.577758
# 998   1   3122   3123   998   5.572890
# 999   1   4801   4802   999   5.572890
#
#                                                  query
# 0    DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# 1    DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# 2    DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# 3    DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# 4    DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# ..                                                 ...
# 995  DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# 996  DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# 997  DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# 998  DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
# 999  DETERMINATION OF THE CURRENT SYSTEMS IN THE UP...
#
# [1000 rows x 6 columns]
# Query ID: 23
# Query Text: OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING THE DISTRIBUTION OF SOURCES ON THE DISC IN THE MICROWAVE RANGE
#
#     qid  docid  docno  rank      score  \
# 0     1     80     81     0  30.592568
# 1     1   4881   4882     1  25.016731
# 2     1   5396   5397     2  24.776227
# 3     1   8190   8191     3  23.606322
# 4     1   9734   9735     4  22.467949
# ..   ..    ...    ...   ...        ...
# 995   1   6589   6590   995   5.506378
# 996   1  10870  10871   996   5.506378
# 997   1   7686   7687   997   5.481468
# 998   1   1831   1832   998   5.465796
# 999   1   2820   2821   999   5.465796
#
#                                                  query
# 0    OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# 1    OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# 2    OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# 3    OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# 4    OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# ..                                                 ...
# 995  OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# 996  OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# 997  OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# 998  OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
# 999  OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING...
#
# [1000 rows x 6 columns]
# Query ID: 24
# Query Text: OBSERVATIONS OF THE SUN USING RADIO INTERFEROMETERS
#
#     qid  docid  docno  rank      score  \
# 0     1   9134   9135     0  21.427094
# 1     1   6307   6308     1  21.309045
# 2     1   2620   2621     2  19.622607
# 3     1   8757   8758     3  18.876926
# 4     1   6484   6485     4  18.458604
# ..   ..    ...    ...   ...        ...
# 995   1   3803   3804   995   4.046848
# 996   1   3920   3921   996   4.046848
# 997   1   9375   9376   997   4.046848
# 998   1  10841  10842   998   4.046848
# 999   1   1540   1541   999   4.039358
#
#                                                  query
# 0    OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# 1    OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# 2    OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# 3    OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# 4    OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# ..                                                 ...
# 995  OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# 996  OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# 997  OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# 998  OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
# 999  OBSERVATIONS OF THE SUN USING RADIO INTERFEROM...
#
# [1000 rows x 6 columns]
# Query ID: 25
# Query Text: EQUATIONS GOVERNING THE PROPAGATION OF ELECTROMAGNETIC AND HYDROMAGNETIC WAVES IN THE SOLAR CORONA
#
#     qid  docid  docno  rank      score  \
# 0     1   1432   1433     0  38.332543
# 1     1   3350   3351     1  30.177445
# 2     1  10980  10981     2  23.354602
# 3     1  11129  11130     3  22.822688
# 4     1   9046   9047     4  22.579096
# ..   ..    ...    ...   ...        ...
# 995   1  10278  10279   995   5.259558
# 996   1   5399   5400   996   5.254864
# 997   1   7029   7030   997   5.254864
# 998   1   8605   8606   998   5.236809
# 999   1   2337   2338   999   5.223775
#
#                                                  query
# 0    EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# 1    EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# 2    EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# 3    EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# 4    EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# ..                                                 ...
# 995  EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# 996  EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# 997  EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# 998  EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
# 999  EQUATIONS GOVERNING THE PROPAGATION OF ELECTRO...
#
# [1000 rows x 6 columns]
# Query ID: 26
# Query Text: ESTIMATES OF THE DENSITY OF IONIZATION AND TEMPERATURE IN THE SOLAR CORONA
#
#     qid  docid docno  rank      score  \
# 0     1   5799  5800     0  29.371454
# 1     1   7225  7226     1  28.587844
# 2     1   2015  2016     2  20.758956
# 3     1   6841  6842     3  20.517611
# 4     1   8178  8179     4  20.396232
# ..   ..    ...   ...   ...        ...
# 995   1   3815  3816   995   5.055370
# 996   1   6007  6008   996   5.049719
# 997   1   2247  2248   997   5.043709
# 998   1   2615  2616   998   5.043709
# 999   1   3201  3202   999   5.043709
#
#                                                  query
# 0    ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# 1    ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# 2    ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# 3    ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# 4    ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# ..                                                 ...
# 995  ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# 996  ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# 997  ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# 998  ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
# 999  ESTIMATES OF THE DENSITY OF IONIZATION AND TEM...
#
# [1000 rows x 6 columns]
# Query ID: 27
# Query Text: PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF LIGHTNING DISCHARGES
#
#     qid  docid  docno  rank      score  \
# 0     1   7773   7774     0  23.346558
# 1     1    123    124     1  21.538229
# 2     1   9159   9160     2  19.653519
# 3     1  10455  10456     3  19.268390
# 4     1   8516   8517     4  18.452077
# ..   ..    ...    ...   ...        ...
# 855   1   4769   4770   855   2.398518
# 856   1   8059   8060   856   2.393330
# 857   1   6714   6715   857   2.352181
# 858   1   4888   4889   858   2.332132
# 859   1   5682   5683   859   2.323166
#
#                                                  query
# 0    PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# 1    PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# 2    PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# 3    PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# 4    PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# ..                                                 ...
# 855  PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# 856  PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# 857  PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# 858  PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
# 859  PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF...
#
# [860 rows x 6 columns]
# Query ID: 28
# Query Text: THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE OF A CAVITY RESONATOR
#
#     qid  docid  docno  rank      score  \
# 0     1   8229   8230     0  24.612165
# 1     1   3615   3616     1  22.693389
# 2     1   3060   3061     2  20.693376
# 3     1   1634   1635     3  19.360460
# 4     1   5471   5472     4  19.009326
# ..   ..    ...    ...   ...        ...
# 995   1   9978   9979   995   4.784891
# 996   1  10143  10144   996   4.784891
# 997   1   2526   2527   997   4.772545
# 998   1   3944   3945   998   4.772545
# 999   1   4205   4206   999   4.772545
#
#                                                  query
# 0    THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# 1    THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# 2    THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# 3    THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# 4    THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# ..                                                 ...
# 995  THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# 996  THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# 997  THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# 998  THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
# 999  THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE...
#
# [1000 rows x 6 columns]
# Query ID: 29
# Query Text: THE DETERMINATION OF THE ORBITS OF INDIVIDUAL METEORS BY RADIO METHODS
#
#     qid  docid  docno  rank      score  \
# 0     1   5393   5394     0  22.371615
# 1     1   9132   9133     1  20.982296
# 2     1   3003   3004     2  20.228941
# 3     1  11123  11124     3  19.231691
# 4     1   9022   9023     4  18.676856
# ..   ..    ...    ...   ...        ...
# 995   1   1239   1240   995   4.395988
# 996   1   1310   1311   996   4.395240
# 997   1   5574   5575   997   4.395240
# 998   1   5820   5821   998   4.390704
# 999   1   8574   8575   999   4.390704
#
#                                                  query
# 0    THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# 1    THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# 2    THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# 3    THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# 4    THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# ..                                                 ...
# 995  THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# 996  THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# 997  THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# 998  THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
# 999  THE DETERMINATION OF THE ORBITS OF INDIVIDUAL ...
#
# [1000 rows x 6 columns]
# Query ID: 30
# Query Text: THE DETERMINATION OF ION MASSES IN THE IONOSPHERE BY THE STUDY OF BACK SCATTERED RADIO WAVES
#
#     qid  docid  docno  rank      score  \
# 0     1   9510   9511     0  34.907478
# 1     1   9509   9510     1  25.059667
# 2     1   1283   1284     2  23.685481
# 3     1   5219   5220     3  23.518313
# 4     1    448    449     4  23.284369
# ..   ..    ...    ...   ...        ...
# 995   1   1233   1234   995   6.120214
# 996   1   6730   6731   996   6.120214
# 997   1   8892   8893   997   6.120214
# 998   1  10567  10568   998   6.120214
# 999   1  10789  10790   999   6.120214
#
#                                                  query
# 0    THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# 1    THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# 2    THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# 3    THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# 4    THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# ..                                                 ...
# 995  THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# 996  THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# 997  THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# 998  THE DETERMINATION OF ION MASSES IN THE IONOSPH...
# 999  THE DETERMINATION OF ION MASSES IN THE IONOSPH...
#
# [1000 rows x 6 columns]
# Query ID: 31
# Query Text: THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQUENCY RADIO WAVES EMITTED FROM THE PLANET JUPITER
#
#     qid  docid docno  rank      score  \
# 0     1   8614  8615     0  35.766196
# 1     1   8392  8393     1  35.715475
# 2     1   3103  3104     2  32.325171
# 3     1   3552  3553     3  26.248465
# 4     1   2741  2742     4  25.906545
# ..   ..    ...   ...   ...        ...
# 995   1    966   967   995   6.166042
# 996   1    123   124   996   6.161259
# 997   1   3811  3812   997   6.161072
# 998   1    181   182   998   6.154916
# 999   1    784   785   999   6.154916
#
#                                                  query
# 0    THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# 1    THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# 2    THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# 3    THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# 4    THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# ..                                                 ...
# 995  THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# 996  THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# 997  THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# 998  THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
# 999  THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQ...
#
# [1000 rows x 6 columns]
# Query ID: 32
# Query Text: SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIGHTNING DISCHARGES
#
#     qid  docid  docno  rank      score  \
# 0     1   1821   1822     0  35.315047
# 1     1   9159   9160     1  30.954138
# 2     1  10455  10456     2  28.045835
# 3     1    913    914     3  27.709038
# 4     1   1447   1448     4  23.569917
# ..   ..    ...    ...   ...        ...
# 995   1   4265   4266   995   3.276482
# 996   1   4494   4495   996   3.276482
# 997   1   4569   4570   997   3.276482
# 998   1   4675   4676   998   3.276482
# 999   1   5215   5216   999   3.276482
#
#                                                  query
# 0    SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# 1    SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# 2    SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# 3    SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# 4    SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# ..                                                 ...
# 995  SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# 996  SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# 997  SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# 998  SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
# 999  SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIG...
#
# [1000 rows x 6 columns]
# Query ID: 33
# Query Text: VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW OR VERY LOW FREQUENCY RADIO WAVES IN THE PERIOD BEFORE GROUND SUNRISE
#
#     qid  docid  docno  rank      score  \
# 0     1   1929   1930     0  16.412173
# 1     1   6133   6134     1  14.622087
# 2     1   5098   5099     2  13.494828
# 3     1   7052   7053     3  13.400901
# 4     1  11261  11262     4  13.342653
# ..   ..    ...    ...   ...        ...
# 995   1   5288   5289   995   4.225100
# 996   1  10671  10672   996   4.213038
# 997   1   4027   4028   997   4.212193
# 998   1   6949   6950   998   4.206053
# 999   1   4409   4410   999   4.205289
#
#                                                  query
# 0    VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# 1    VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# 2    VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# 3    VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# 4    VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# ..                                                 ...
# 995  VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# 996  VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# 997  VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# 998  VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
# 999  VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW ...
#
# [1000 rows x 6 columns]
# Query ID: 34
# Query Text: THE USE OF IONOSPHERIC CROSS MODULATION IN THE DETERMINATION OF IONOSPHERIC ELECTRON DENSITIES AND COLLISION FREQUENCIES
#
#     qid  docid  docno  rank      score  \
# 0     1  11262  11263     0  14.566411
# 1     1  10992  10993     1  14.423894
# 2     1   7634   7635     2  13.539373
# 3     1   2728   2729     3  13.409198
# 4     1  10125  10126     4  13.151581
# ..   ..    ...    ...   ...        ...
# 995   1   4290   4291   995   4.043450
# 996   1   9659   9660   996   4.041956
# 997   1   4670   4671   997   4.040092
# 998   1  10376  10377   998   4.040092
# 999   1    115    116   999   4.038006
#
#                                                  query
# 0    THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# 1    THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# 2    THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# 3    THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# 4    THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# ..                                                 ...
# 995  THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# 996  THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# 997  THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# 998  THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
# 999  THE USE OF IONOSPHERIC CROSS MODULATION IN THE...
#
# [1000 rows x 6 columns]
# Query ID: 35
# Query Text: MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQUATOR
#
#     qid  docid  docno  rank      score  \
# 0     1   2143   2144     0  27.180706
# 1     1   3702   3703     1  21.515726
# 2     1   1557   1558     2  19.074982
# 3     1  10296  10297     3  18.061446
# 4     1  11298  11299     4  17.210414
# ..   ..    ...    ...   ...        ...
# 995   1   1904   1905   995   4.535221
# 996   1   2516   2517   996   4.535221
# 997   1   2655   2656   997   4.535221
# 998   1   2762   2763   998   4.535221
# 999   1   3103   3104   999   4.535221
#
#                                                  query
# 0    MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# 1    MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# 2    MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# 3    MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# 4    MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# ..                                                 ...
# 995  MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# 996  MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# 997  MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# 998  MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
# 999  MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQ...
#
# [1000 rows x 6 columns]
# Query ID: 36
# Query Text: THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPHERE THEORY
#
#     qid  docid  docno  rank      score  \
# 0     1   2673   2674     0  17.673018
# 1     1    374    375     1  17.544965
# 2     1    773    774     2  17.507422
# 3     1   1550   1551     3  16.408374
# 4     1   3037   3038     4  16.334038
# ..   ..    ...    ...   ...        ...
# 995   1   7062   7063   995   4.416894
# 996   1  10517  10518   996   4.416894
# 997   1  10906  10907   997   4.416894
# 998   1  11058  11059   998   4.416894
# 999   1   2787   2788   999   4.412998
#
#                                                  query
# 0    THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# 1    THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# 2    THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# 3    THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# 4    THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# ..                                                 ...
# 995  THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# 996  THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# 997  THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# 998  THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
# 999  THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPH...
#
# [1000 rows x 6 columns]
# Query ID: 37
# Query Text: THE USE OF LUNAR RADIO REFLECTIONS IN INVESTIGATIONS OF THE NATURE OF THE MOONS SURFACE
#
#     qid  docid docno  rank      score  \
# 0     1     85    86     0  34.905680
# 1     1   2255  2256     1  31.185387
# 2     1   9483  9484     2  29.527089
# 3     1   1251  1252     3  27.056421
# 4     1   4024  4025     4  26.511234
# ..   ..    ...   ...   ...        ...
# 995   1    934   935   995   4.644733
# 996   1   1858  1859   996   4.644733
# 997   1   2486  2487   997   4.644733
# 998   1   6829  6830   998   4.644733
# 999   1   7335  7336   999   4.644733
#
# ...
# 997  I WISH TO CALCULATE THE INDUCTANCE AND LOSS IN...
# 998  I WISH TO CALCULATE THE INDUCTANCE AND LOSS IN...
# 999  I WISH TO CALCULATE THE INDUCTANCE AND LOSS IN...
#
# [1000 rows x 6 columns]
# Query ID: 82
# Query Text: ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLANE TECHNIQUES
#
#     qid  docid  docno  rank      score  \
# 0     1   6415   6416     0  25.474818
# 1     1   3706   3707     1  20.294551
# 2     1   1075   1076     2  18.630943
# 3     1   4412   4413     3  17.842040
# 4     1   7379   7380     4  17.604991
# ..   ..    ...    ...   ...        ...
# 995   1  10166  10167   995   5.668430
# 996   1   3066   3067   996   5.666931
# 997   1   4949   4950   997   5.666931
# 998   1   7345   7346   998   5.666531
# 999   1   6026   6027   999   5.661985
#
#                                                  query
# 0    ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# 1    ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# 2    ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# 3    ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# 4    ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# ..                                                 ...
# 995  ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# 996  ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# 997  ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# 998  ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
# 999  ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLAN...
#
# [1000 rows x 6 columns]
# Query ID: 83
# Query Text: MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE AMPLIFIERS
#
#     qid  docid  docno  rank      score  \
# 0     1   4628   4629     0  15.128782
# 1     1   9806   9807     1  14.535266
# 2     1   8569   8570     2  14.353146
# 3     1   1084   1085     3  14.023194
# 4     1   4623   4624     4  13.840038
# ..   ..    ...    ...   ...        ...
# 995   1  10792  10793   995   3.714390
# 996   1   6247   6248   996   3.702611
# 997   1  11326  11327   997   3.697100
# 998   1   3497   3498   998   3.686027
# 999   1   6766   6767   999   3.682522
#
#                                                  query
# 0    MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# 1    MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# 2    MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# 3    MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# 4    MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# ..                                                 ...
# 995  MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# 996  MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# 997  MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# 998  MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
# 999  MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE A...
#
# [1000 rows x 6 columns]
# Query ID: 84
# Query Text: CONTROL CHARACTERISTICS OF SAMPLING SERVO SYSTEMS
#
#     qid  docid docno  rank      score  \
# 0     1   4411  4412     0  25.227254
# 1     1   6137  6138     1  24.631197
# 2     1   6946  6947     2  23.133633
# 3     1   7761  7762     3  22.711208
# 4     1   6865  6866     4  22.654386
# ..   ..    ...   ...   ...        ...
# 995   1   4626  4627   995   4.166445
# 996   1   5292  5293   996   4.166445
# 997   1   5533  5534   997   4.166445
# 998   1   7528  7529   998   4.166445
# 999   1   8839  8840   999   4.166445
#
#                                                  query
# 0    CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# 1    CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# 2    CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# 3    CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# 4    CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# ..                                                 ...
# 995  CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# 996  CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# 997  CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# 998  CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
# 999  CONTROL CHARACTERISTICS OF SAMPLING SERVO SYST...
#
# [1000 rows x 6 columns]
# Query ID: 85
# Query Text: POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED USING ANALOGUE TECHNIQUES
#
#     qid  docid  docno  rank      score  \
# 0     1  10385  10386     0  17.744574
# 1     1   5331   5332     1  17.127007
# 2     1   5447   5448     2  16.824680
# 3     1    113    114     3  16.595085
# 4     1   3042   3043     4  16.493501
# ..   ..    ...    ...   ...        ...
# 995   1   3471   3472   995   5.923679
# 996   1   8069   8070   996   5.908331
# 997   1    272    273   997   5.907120
# 998   1    574    575   998   5.907120
# 999   1   1824   1825   999   5.907120
#
#                                                  query
# 0    POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# 1    POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# 2    POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# 3    POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# 4    POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# ..                                                 ...
# 995  POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# 996  POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# 997  POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# 998  POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
# 999  POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED U...
#
# [1000 rows x 6 columns]
# Query ID: 86
# Query Text: HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTORISED ANALOGUE AMPLIFIER
#
#     qid  docid  docno  rank      score  \
# 0     1   6682   6683     0  14.881551
# 1     1   4450   4451     1  14.307885
# 2     1   3529   3530     2  14.190372
# 3     1  11051  11052     3  13.757211
# 4     1   8843   8844     4  13.520957
# ..   ..    ...    ...   ...        ...
# 995   1   6110   6111   995   3.512971
# 996   1   7812   7813   996   3.512971
# 997   1   8895   8896   997   3.512971
# 998   1  10080  10081   998   3.512971
# 999   1  10181  10182   999   3.512971
#
#                                                  query
# 0    HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# 1    HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# 2    HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# 3    HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# 4    HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# ..                                                 ...
# 995  HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# 996  HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# 997  HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# 998  HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
# 999  HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTOR...
#
# [1000 rows x 6 columns]
# Query ID: 87
# Query Text: ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR SHOWING A DISCONTINUITY AT THE SUPERCONDUCTING CRITICAL TEMPERATURE
#
#     qid  docid  docno  rank      score  \
# 0     1   3313   3314     0  28.758384
# 1     1  10743  10744     1  23.459093
# 2     1   3664   3665     2  22.411430
# 3     1   2355   2356     3  21.056832
# 4     1   4969   4970     4  20.548998
# ..   ..    ...    ...   ...        ...
# 995   1   2013   2014   995   4.303227
# 996   1   5078   5079   996   4.303227
# 997   1   5967   5968   997   4.303227
# 998   1   7032   7033   998   4.303227
# 999   1   7277   7278   999   4.303227
#
#                                                  query
# 0    ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# 1    ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# 2    ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# 3    ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# 4    ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# ..                                                 ...
# 995  ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# 996  ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# 997  ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# 998  ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
# 999  ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR S...
#
# [1000 rows x 6 columns]
# Query ID: 88
# Query Text: AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUNDING A CHARGED THIN CIRCULAR DISC RESTING ON AN INFINITE DIELECTRIC SLAB
#
#     qid  docid  docno  rank      score  \
# 0     1   3547   3548     0  32.959716
# 1     1  10805  10806     1  22.473596
# 2     1   9457   9458     2  22.108833
# 3     1  10067  10068     3  21.399241
# 4     1   7830   7831     4  21.054011
# ..   ..    ...    ...   ...        ...
# 995   1    241    242   995   5.065907
# 996   1   4997   4998   996   5.065907
# 997   1   8063   8064   997   5.065907
# 998   1   4044   4045   998   5.060017
# 999   1   5897   5898   999   5.060017
#
#                                                  query
# 0    AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# 1    AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# 2    AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# 3    AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# 4    AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# ..                                                 ...
# 995  AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# 996  AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# 997  AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# 998  AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
# 999  AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUND...
#
# [1000 rows x 6 columns]
# Query ID: 89
# Query Text: TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL CHARACTERISTICS EXPLAINED
#
#     qid  docid  docno  rank      score  \
# 0     1    943    944     0  22.876175
# 1     1  10901  10902     1  22.250555
# 2     1   3936   3937     2  22.037593
# 3     1  11205  11206     3  21.099298
# 4     1   2286   2287     4  20.785201
# ..   ..    ...    ...   ...        ...
# 995   1   4733   4734   995   4.545985
# 996   1  10319  10320   996   4.545985
# 997   1   5620   5621   997   4.545435
# 998   1     52     53   998   4.544812
# 999   1    276    277   999   4.544812
#
#                                                  query
# 0    TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# 1    TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# 2    TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# 3    TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# 4    TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# ..                                                 ...
# 995  TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# 996  TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# 997  TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# 998  TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
# 999  TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL C...
#
# [1000 rows x 6 columns]
# Query ID: 90
# Query Text: ELECTRONIC DENSITY OF STATES AT THE SURFACE OF A SEMICONDUCTOR COMPARED WITH THAT AT DEPTH
#
#     qid  docid docno  rank      score  \
# 0     1   7010  7011     0  22.198321
# 1     1   6189  6190     1  22.139186
# 2     1   1347  1348     2  17.848293
# 3     1   5283  5284     3  17.752037
# 4     1   6580  6581     4  17.221971
# ..   ..    ...   ...   ...        ...
# 995   1    661   662   995   5.204460
# 996   1   1193  1194   996   5.204460
# 997   1   1350  1351   997   5.204460
# 998   1   3388  3389   998   5.204460
# 999   1   3737  3738   999   5.204460
#
#                                                  query
# 0    ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# 1    ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# 2    ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# 3    ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# 4    ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# ..                                                 ...
# 995  ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# 996  ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# 997  ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# 998  ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
# 999  ELECTRONIC DENSITY OF STATES AT THE SURFACE OF...
#
# [1000 rows x 6 columns]
# Query ID: 91
# Query Text: RESISTIVITY OF METALLIC THIN FILMS RELATED TO SURFACE ROUGHNESS
#
#     qid  docid docno  rank      score  \
# 0     1   6580  6581     0  29.867415
# 1     1   7593  7594     1  29.478952
# 2     1   4750  4751     2  26.743952
# 3     1   7602  7603     3  25.471888
# 4     1   9223  9224     4  25.118500
# ..   ..    ...   ...   ...        ...
# 995   1    950   951   995   3.732731
# 996   1   5154  5155   996   3.732731
# 997   1   6760  6761   997   3.732731
# 998   1   7371  7372   998   3.732731
# 999   1   7721  7722   999   3.732731
#
#                                                  query
# 0    RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# 1    RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# 2    RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# 3    RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# 4    RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# ..                                                 ...
# 995  RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# 996  RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# 997  RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# 998  RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
# 999  RESISTIVITY OF METALLIC THIN FILMS RELATED TO ...
#
# [1000 rows x 6 columns]
# Query ID: 92
# Query Text: THE PHENOMENON OF RADIATION CAUSED BY CHARGED PARTICLES MOVING IN VARYING ELECTRIC AND MAGNETIC FIELDS
#
#     qid  docid  docno  rank      score  \
# 0     1   1378   1379     0  32.049712
# 1     1   8713   8714     1  29.324028
# 2     1   8723   8724     2  29.196406
# 3     1   8380   8381     3  27.749550
# 4     1   8872   8873     4  26.857609
# ..   ..    ...    ...   ...        ...
# 995   1   8911   8912   995   6.881458
# 996   1   9456   9457   996   6.881458
# 997   1   8473   8474   997   6.878976
# 998   1   2492   2493   998   6.877154
# 999   1  10833  10834   999   6.877154
#
#                                                  query
# 0    THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# 1    THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# 2    THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# 3    THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# 4    THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# ..                                                 ...
# 995  THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# 996  THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# 997  THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# 998  THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
# 999  THE PHENOMENON OF RADIATION CAUSED BY CHARGED ...
#
# [1000 rows x 6 columns]
# Query ID: 93
# Query Text: HIGH FREQUENCY OSCILLATORS USING TRANSISTORS THEORETICAL TREATMENT AND PRACTICAL CIRCUIT DETAILS
#
#     qid  docid docno  rank      score  \
# 0     1   2963  2964     0  31.657666
# 1     1   1975  1976     1  24.404839
# 2     1   7801  7802     2  24.078172
# 3     1    532   533     3  23.316152
# 4     1    150   151     4  22.482757
# ..   ..    ...   ...   ...        ...
# 995   1   5495  5496   995   8.163870
# 996   1   9187  9188   996   8.163650
# 997   1   4821  4822   997   8.163588
# 998   1   3279  3280   998   8.163573
# 999   1   9701  9702   999   8.163573
#
#                                                  query
# 0    HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# 1    HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# 2    HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# 3    HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# 4    HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# ..                                                 ...
# 995  HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# 996  HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# 997  HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# 998  HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
# 999  HIGH FREQUENCY OSCILLATORS USING TRANSISTORS T...
#
# [1000 rows x 6 columns]

# %%
class Ranker:

  def rank(self,index):
      TF_IDF =  pt.BatchRetrieve(index, wmodel= "TF_IDF")
      TF =  pt.BatchRetrieve(index, wmodel= "Tf")
      BM25 = pt.BatchRetrieve(index, wmodel= "BM25")
      pipeline = (TF_IDF | TF) >> BM25
      return pipeline

# %%
# réponse Q2
ranker = Ranker()
pipeline = ranker.rank(index_ref)
print(pipeline)
# Out:
# Compose(Union(BR(TF_IDF), BR(Tf)), BR(BM25))

# %%
for query in dataset.queries_iter():
    query_text = query.text
    query_id = query.query_id

    results = pipeline.search("Radiation")

    print(f"Query ID: {query_id}")
    print(f"Query Text: {query_text}")
    print(results)
# Out:
# Query ID: 1
# Query Text: MEASUREMENT OF DIELECTRIC CONSTANT OF LIQUIDS BY THE USE OF MICROWAVE TECHNIQUES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 2
# Query Text: MATHEMATICAL ANALYSIS AND DESIGN DETAILS OF WAVEGUIDE FED MICROWAVE RADIATIONS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 3
# Query Text: USE OF DIGITAL COMPUTERS IN THE DESIGN OF BAND PASS FILTERS HAVING GIVEN PHASE AND ATTENUATION CHARACTERISTICS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 4
# Query Text: SYSTEMS OF DATA CODING FOR INFORMATION TRANSFER
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 5
# Query Text: USE OF PROGRAMS IN ENGINEERING TESTING OF COMPUTERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 6
# Query Text: NUMBER REPRESENTATION IN BINARY MACHINES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 7
# Query Text: SECONDARY EMISSION OF ELECTRONS BY POSITIVE ION BOMBARDMENT OF THE CATHODE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 8
# Query Text: MEASUREMENT OF PLASMA TEMPERATURES IN ARC DISCHARGE USING SHOCK WAVE TECHNIQUES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 9
# Query Text: CHARACTERISTICS OF THE SINGLE ELECTRODE DISCHARGE IN THE RARE GASES AT LOW PRESSURES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 10
# Query Text: METHODS OF CALCULATING INSTANTANEOUS POWER DISSIPATION IN REACTIVE CIRCUITS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 11
# Query Text: THE EFFECT OF OXIDATION ON CIRCUIT BREAKER CONTACTS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 12
# Query Text: TEMPERATURE INDEPENDENT METHODS FOR TUNING HIGHLY STABLE HIGH FREQUENCY OSCILLATORS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 13
# Query Text: MATHEMATICAL EXPRESSIONS AND GRAPHS FOR THE DESIGN OF TRANSISTORISED TUNED PASS BAND AMPLIFIERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 14
# Query Text: SYNTHESIS OF FILTERS HAVING HIGH ATTENUATION CHARACTERISTICS USING A BLOCK DIAGRAM APPROACH
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 15
# Query Text: VOLTAGE CURRENT RELATIONSHIPS IN NETWORKS OF NONLINEAR ELEMENTS CONNECTED IN PARALLEL
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 16
# Query Text: METHODS OF APPROXIMATING THE FREQUENCY PHASE RELATIONSHIPS FOR RESISTIVE INDUCTIVE AND RESISTIVE CAPACITIVE CIRCUITS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 17
# Query Text: OBSERVATIONS OF RAPID FLUCTUATIONS IN THE EARTHS MAGNETIC FIELD AND THEIR RELATION TO THE PROPAGATION OF HYDROMAGNETIC WAVES IN THE
# EXOSPHERE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 18
# Query Text: DIURNAL VARIATIONS OF FLUCTUATIONS IN THE EARTHS MAGNETIC FIELD
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 19
# Query Text: SPHERICAL HARMONIC ANALYSIS OF THE EARTHS MAGNETIC FIELD
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 20
# Query Text: DERIVATION OF THE COMPONENTS OF THE ELECTRICAL CONDUCTIVITY IN THE UPPER ATMOSPHERE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 21
# Query Text: THE EFFECTS OF SOLAR FLARES ON THE ABSORPTION OF COSMIC RADIO NOISE IN THE IONOSPHERE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 22
# Query Text: DETERMINATION OF THE CURRENT SYSTEMS IN THE UPPER ATMOSPHERE DURING MAGNETIC STORMS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 23
# Query Text: OBSERVATIONS OF THE SUN DURING ECLIPSES GIVING THE DISTRIBUTION OF SOURCES ON THE DISC IN THE MICROWAVE RANGE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 24
# Query Text: OBSERVATIONS OF THE SUN USING RADIO INTERFEROMETERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 25
# Query Text: EQUATIONS GOVERNING THE PROPAGATION OF ELECTROMAGNETIC AND HYDROMAGNETIC WAVES IN THE SOLAR CORONA
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 26
# Query Text: ESTIMATES OF THE DENSITY OF IONIZATION AND TEMPERATURE IN THE SOLAR CORONA
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 27
# Query Text: PLEASE SEND ABSTRACTS ON THE SOURCE SPECTRA OF LIGHTNING DISCHARGES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 28
# Query Text: THE EFFECT OF SMALL DISTORTIONS IN THE SURFACE OF A CAVITY RESONATOR
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 29
# Query Text: THE DETERMINATION OF THE ORBITS OF INDIVIDUAL METEORS BY RADIO METHODS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 30
# Query Text: THE DETERMINATION OF ION MASSES IN THE IONOSPHERE BY THE STUDY OF BACK SCATTERED RADIO WAVES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 31
# Query Text: THEORETICAL STUDIES OF THE SOURCE OF HIGH FREQUENCY RADIO WAVES EMITTED FROM THE PLANET JUPITER
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 32
# Query Text: SIMULTANEOUS OBSERVATIONS OF WHISTLERS AND LIGHTNING DISCHARGES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 33
# Query Text: VARIATIONS IN THE HEIGHT OF REFLECTION OF LOW OR VERY LOW FREQUENCY RADIO WAVES IN THE PERIOD BEFORE GROUND SUNRISE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 34
# Query Text: THE USE OF IONOSPHERIC CROSS MODULATION IN THE DETERMINATION OF IONOSPHERIC ELECTRON DENSITIES AND COLLISION FREQUENCIES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 35
# Query Text: MEASUREMENTS OF IONOSPHERIC DRIFTS NEAR THE EQUATOR
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 36
# Query Text: THE USE OF ANALOGUE COMPUTERS IN UPPER ATMOSPHERE THEORY
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 37
# Query Text: THE USE OF LUNAR RADIO REFLECTIONS IN INVESTIGATIONS OF THE NATURE OF THE MOONS SURFACE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 38
# Query Text: WHAT REFERENCES ON COMPARISON BETWEEN GROUND LEVEL AND HIGH ALTITUDE BALLOON COSMIC RAY RESULTS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 39
# Query Text: WHAT REFERENCES ON MODEL EXPERIMENTS IN AURORA
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 40
# Query Text: WHAT REFERENCES ON INTEGRAL SPECTRUM OF PRIMARY COSMIC RAYS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 41
# Query Text: FERROMAGNETIC TECHNIQUES FOR COMPUTER STORES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 42
# Query Text: SOLUTION OF DIFFERENTIAL EQUATIONS BY COMPUTER
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 43
# Query Text: EFFICIENCY OF DIGITAL COMPUTERS VERSUS ANALOGUE COMPUTERS IN THE SOLUTION OF BOUNDARY VALUE PROBLEMS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 44
# Query Text: METHODS OF ERROR CHECKING IN DIGITAL COMPUTERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 45
# Query Text: METHODS OF PRODUCING MINIMAL NETS GIVEN A LOGICAL FUNCTION IN CANONICAL FORM
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 46
# Query Text: ARITHMETIC UNITS AS REQUIRED IN A DIGITAL COMPUTER INCLUDING SHIFT REGISTERS SERIAL AND PARALLEL ADDER
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 47
# Query Text: INFORMATION ON THE DESIGN OF LOW DRIFT TRANSISTOR AMPLIFIERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 48
# Query Text: INFORMATION ON HIGH CURRENT TRANSISTOR SWITCHES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 49
# Query Text: INFORMATION ON DESIGN OF TIME DIVISION MULTIPLEXING CIRCUITS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 50
# Query Text: DETAILS OF AVAILABLE LOW VOLTAGE CAPACITORS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 51
# Query Text: DESIGN OF DIRECT COUPLED FLIP FLOPS TO FUNCTION WITH THE MAXIMUM VARIATIONS IN THE VALUES OF THE CIRCUIT COMPONENTS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 52
# Query Text: PLEASE SUPPLY INFORMATION ON THE PERFORMANCE OF TYPICAL MAGNETIC FILM MEMORY SYSTEMS WITH CIRCUIT DIAGRAMS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 53
# Query Text: I WOULD LIKE DETAILS OF THE WORK WHICH HAS BEEN DONE TO EXTEND THE FREQUENCY RANGE OF MAGNETIC AMPLIFIERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 54
# Query Text: I WOULD LIKE INFORMATION ON THE RANGE OF STATIC RELAYS SUITABLE FOR USE AT HIGH SWITCHING RATES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 55
# Query Text: I AM INTERESTED IN CIRCUITRY CAPABLE OF GENERATING EXTREMELY NARROW PULSES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 56
# Query Text: PLEASE SUPPLY INFORMATION ON THE THEORY AND USE OF PARAMETRIC AMPLIFIERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 57
# Query Text: THE SYNTHESIS OF NETWORKS WITH GIVEN SAMPLED DATA TRANSFER FUNCTIONS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 58
# Query Text: THE THEORY OF STABILITY IN RELATION TO CONTROL SYSTEMS WITH RELAY ELEMENTS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 59
# Query Text: THE USE OF DIGITAL COMPUTERS TO OBTAIN POWER SPECTRAL ANALYSIS OF NUMERICAL DATA
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 60
# Query Text: PRINTED CIRCUIT DESIGN FOR A RANDOM PULSE GENERATOR OF LOW FREQUENCY
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 61
# Query Text: REFERENCES ON ELECTRIC FIELD THEORIES OF THE AURORA
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 62
# Query Text: FAST TRANSISTOR COUNTERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 63
# Query Text: LOW PASS LATTICE FILTERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 64
# Query Text: SIMILARITIES BETWEEN THE DIFFRACTION THEORY OF ELECTROMAGNETIC WAVES AND THAT OF ELECTRON STREAMS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 65
# Query Text: THE USE OF COMPLEX VARIABLES IN THE THEORY OF COMMUNICATION NETWORKS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 66
# Query Text: THE BEHAVIOUR OF A BEAM OF CHARGED PARTICLES IN THE PRESENCE OF PLANE CONDUCTORS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 67
# Query Text: PREDICTING THE PATHS OF ELECTRONS MOVING IN A VARYING MAGNETIC FIELD
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 68
# Query Text: ACTIVE CONSTANT VOLTAGE TRANSFORMER FOR SIGNAL DISTRIBUTION
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 69
# Query Text: ACTIVE AUDIO FREQUENCY FILTER WITH VARIABLE CUT OFF SLOPE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# ...
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 72
# Query Text: VARIABLE CAPACITANCE AMPLIFIERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 73
# Query Text: TRANSISTOR SWEEP GENERATORS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 74
# Query Text: ADVANTAGES OF PARAMETRIC AMPLIFIERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 75
# Query Text: OPTIMISING LINEAR NETWORKS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 76
# Query Text: TRANSISTOR PHASE SPLITTING CIRCUITS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 77
# Query Text: PLEASE SUPPLY INFORMATION PERTINENT TO THE USE OF SURFACE PRETREATMENT TO PREVENT SECONDARY EMISSION EFFECTS IN VALVES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 78
# Query Text: I WISH TO HAVE DATA ABOUT THE DESIGN OF MECHANICAL BAND PASS FILTERS FOR GOOD PASS CHARACTERISTICS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 79
# Query Text: MECHANISMS WHEREBY TRANSMISSION AT HIGH FREQUENCIES IS AFFECTED BY WEATHER AND TIME OF DAY
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 80
# Query Text: COULD YOU PLEASE GIVE ME ARTICLES ABOUT THE POSSIBILITIES OF GETTING RECTIFICATION USING METALLIC DEVICES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 81
# Query Text: I WISH TO CALCULATE THE INDUCTANCE AND LOSS IN COILS MADE USING PRINTED CIRCUIT OR OTHER MINIATURIZATION IDEAS. A SUITABLE ARTICLE
# PLEASE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 82
# Query Text: ANALYSIS OF NONLINEAR SYSTEMS USING PHASE PLANE TECHNIQUES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 83
# Query Text: MINIATURE LOW NOISE HIGH GAIN HIGH IMPEDANCE AMPLIFIERS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 84
# Query Text: CONTROL CHARACTERISTICS OF SAMPLING SERVO SYSTEMS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 85
# Query Text: POWER SPECTRAL DENSITY DISTRIBUTION OBTAINED USING ANALOGUE TECHNIQUES
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 86
# Query Text: HIGH STABILITY HIGH INPUT IMPEDANCE TRANSISTORISED ANALOGUE AMPLIFIER
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 87
# Query Text: ELECTRONIC SPECIFIC HEAT OF A SUPERCONDUCTOR SHOWING A DISCONTINUITY AT THE SUPERCONDUCTING CRITICAL TEMPERATURE
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 88
# Query Text: AN ABSTRACT ON THE FIELD DISTRIBUTION SURROUNDING A CHARGED THIN CIRCULAR DISC RESTING ON AN INFINITE DIELECTRIC SLAB
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 89
# Query Text: TUNNEL DIODE CONSTRUCTION AND ITS ELECTRICAL CHARACTERISTICS EXPLAINED
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 90
# Query Text: ELECTRONIC DENSITY OF STATES AT THE SURFACE OF A SEMICONDUCTOR COMPARED WITH THAT AT DEPTH
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 91
# Query Text: RESISTIVITY OF METALLIC THIN FILMS RELATED TO SURFACE ROUGHNESS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 92
# Query Text: THE PHENOMENON OF RADIATION CAUSED BY CHARGED PARTICLES MOVING IN VARYING ELECTRIC AND MAGNETIC FIELDS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
# Query ID: 93
# Query Text: HIGH FREQUENCY OSCILLATORS USING TRANSISTORS THEORETICAL TREATMENT AND PRACTICAL CIRCUIT DETAILS
#
#     qid  docid docno  rank     score      query
# 0     1   4874  4875     0  7.320891  Radiation
# 1     1   1135  1136     1  7.238332  Radiation
# 2     1   8511  8512     2  7.075086  Radiation
# 3     1   2850  2851     3  6.972942  Radiation
# 4     1    860   861     4  6.828960  Radiation
# ..   ..    ...   ...   ...       ...        ...
# 601   1   8059  8060   601  2.112368  Radiation
# 602   1   8620  8621   602  2.112368  Radiation
# 603   1   4888  4889   603  2.058354  Radiation
# 604   1   6405  6406   604  1.942459  Radiation
# 605   1   2899  2900   605  1.496951  Radiation
#
# [606 rows x 6 columns]
